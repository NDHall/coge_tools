# %% [markdown]
# import pandas as pd

# %% [markdown]
# This NoteBook is an intial look at blocks of putative zero expression across all data sets.
# We find through previous data summation that there are too many None or non called AB contigs to get a clear or honest signal. Instead we are going to try and focus on the largest called contig and its homeologs. Here we find that largest set of zero blocks belongs to Super-Scaffold-7 a strong A called contig.

# %%
df = pd.read_csv('/home/ndh0004/Documents/cor_exp/raw_total_counts/clusters.tsv',
                 sep='\t')

# %%
df['total'] = df['block_len'] * df['num']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9039366907f5> in <module>()
# ----> 1 df['total'] = df['block_len'] * df['num']
#
# NameError: name 'df' is not defined

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contig</th>
#       <th>block_len</th>
#       <th>num</th>
#       <th>total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Super-Scaffold_352</td>
#       <td>1</td>
#       <td>16</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Super-Scaffold_352</td>
#       <td>2</td>
#       <td>6</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Super-Scaffold_352</td>
#       <td>3</td>
#       <td>2</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Super-Scaffold_352</td>
#       <td>5</td>
# ...

# %%
dfg = df[['contig', 'total']].groupby(['contig']).sum().reset_index()

# %%
dfg_max = dfg.max()
dfg
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contig</th>
#       <th>total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Super-Scaffold_1</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Super-Scaffold_10</td>
#       <td>65</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Super-Scaffold_100</td>
#       <td>53</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Super-Scaffold_1001</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Super-Scaffold_1005</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
# ...

# %%
dfg_max
# Out:
# contig    scaffold998|size260683_obj
# total                           1378
# dtype: object

# %%
dfgt10 = df.loc[df['block_len']>=10]

# %%
dfgt10_tot = df[['contig','total']].groupby(['contig']).sum().reset_index()

# %%
dfgt10_tot.max()
# Out:
# contig    scaffold998|size260683_obj
# total                           1378
# dtype: object

# %%
dfgt10_tot.loc[dfgt10_tot['total'] == 1378 ]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>contig</th>
#       <th>total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>452</th>
#       <td>Super-Scaffold_7</td>
#       <td>1378</td>
#     </tr>
#   </tbody>
# </table>
# </div>
